# %% [markdown]
# # Setup & Package Versions

# %% [markdown]
# Below list display's the versions that are required to run any GitHub scripts. The same code can simply be entered into an open conda command-line window. More details see e.g. [here](https://www.activestate.com/resources/quick-reads/how-to-list-installed-python-packages/).
#
# In case you need to downgrade to an older/earlier version of a package use (e.g.) the following code in your command line:
#
# `conda install numpy==1.18.1`  or
# `pip install pandas==1.0.0`

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\Ben Zimmermann\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py39haa95532_0
# absl-py                   1.0.0                    pypi_0    pypi
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  2021.11                  py39_0
# anaconda-client           1.9.0            py39haa95532_0
# anaconda-navigator        2.1.1                    py39_0
# anaconda-project          0.10.1             pyhd3eb1b0_0
# anyio                     2.2.0            py39haa95532_2
# appdirs                   1.4.4              pyhd3eb1b0_0
# argh                      0.26.2           py39haa95532_0
# argon2-cffi               20.1.0           py39h2bbff1b_1
# arrow                     0.13.1           py39haa95532_0
# asgiref                   3.4.1                    pypi_0    pypi
# asn1crypto                1.4.0                      py_0
# ...

# %%
from platform import python_version

print(python_version())
# Out:
# 3.9.7
